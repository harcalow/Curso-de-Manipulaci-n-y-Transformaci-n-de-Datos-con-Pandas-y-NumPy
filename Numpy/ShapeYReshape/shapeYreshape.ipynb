# %%
import numpy as np

# %%
array=np.random.randint(1,10,(3,2))
array
# Out:
# array([[7, 8],
#        [7, 9],
#        [4, 2]])

# %%
array.shape
# Out:
# (3, 2)

# %%
array.reshape(1,6)
# Out:
# array([[7, 8, 7, 9, 4, 2]])

# %%
array.reshape(2,3)
# Out:
# array([[7, 8, 7],
#        [9, 4, 2]])

# %%
np.reshape(array,(1,6))
# Out:
# array([[7, 8, 7, 9, 4, 2]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.reshape(array,(2,3),'C')
# Out:
# array([[7, 8, 7],
#        [9, 4, 2]])

# %%
array
# Out:
# array([[7, 8],
#        [7, 9],
#        [4, 2]])

# %%
np.reshape(array,(2,3),'F')
# Out:
# array([[7, 4, 9],
#        [7, 8, 2]])

# %% [markdown]
# Como lo optimiza mi computador se coloca la letra A

# %%
np.reshape(array,(2,3),'A')
# Out:
# array([[7, 8, 7],
#        [9, 4, 2]])
